# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Obtaining dependency information for lightgbm from https://files.pythonhosted.org/packages/e1/4c/4685ccfae9806f561de716e32549190c1f533dde5bcadaf83bdf23972cf0/lightgbm-4.3.0-py3-none-win_amd64.whl.metadata
#   Downloading lightgbm-4.3.0-py3-none-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\lhuup\anaconda3\lib\site-packages (from lightgbm) (1.24.3)
# Requirement already satisfied: scipy in c:\users\lhuup\anaconda3\lib\site-packages (from lightgbm) (1.11.1)
# Downloading lightgbm-4.3.0-py3-none-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.3 MB 660.6 kB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.3 MB 812.7 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.3 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.3 MB 1.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.7/1.3 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.3 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.1/1.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
X_train = pd.read_csv(r"D:\Machine Learning\Final Project DEADLINE 17-5\Prediction-House-Price\Data\handle data\X_train.csv")
y_train = pd.read_csv(r"D:\Machine Learning\Final Project DEADLINE 17-5\Prediction-House-Price\Data\handle data\y_train.csv")
X_test =  pd.read_csv(r"D:\Machine Learning\Final Project DEADLINE 17-5\Prediction-House-Price\Data\handle data\X_test.csv")
y_test = pd.read_csv(r"D:\Machine Learning\Final Project DEADLINE 17-5\Prediction-House-Price\Data\handle data\y_test.csv")

# %%
#lightgbm model
model = lgb.LGBMRegressor(num_leaves= 14, max_depth = 17, 
                         random_state = 314, 
                         silent = True,
                         objective = 'regression',
                         metric = 'auc', 
                         device_type = 'gpu',
                         n_estimators = 1000,
                         colsample_bytree = 0.9,
                         subsample = 0.8,
                         bagging_freq = 7,
                         learning_rate = 0.1, 
                       )

# %%
model.fit(X_train, y_train, eval_set = [(X_test,y_test)],eval_metric = 'l1')
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 3157
# [LightGBM] [Info] Number of data points in the train set: 1168, number of used features: 36
# [LightGBM] [Info] Using GPU Device: gfx902, Vendor: Advanced Micro Devices, Inc.
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005292 secs. 1 sparse feature groups
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Info] Start training from score 181441.541952
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004852 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004592 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004625 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004615 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004735 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004562 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004557 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004418 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004662 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004668 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.005454 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004487 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004603 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004498 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004519 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004413 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.006329 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004738 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004820 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005124 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004673 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004630 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004321 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004622 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004490 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004674 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004634 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004828 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004493 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004628 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004665 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004531 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004500 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004534 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004451 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004822 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004478 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004546 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004631 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004506 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004503 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004690 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004676 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004668 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004865 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004612 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004688 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004459 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004724 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004662 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004676 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004648 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004554 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004706 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004785 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004753 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004621 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004600 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004608 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004801 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005612 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004701 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004742 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004599 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004541 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004497 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004596 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004693 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004873 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004510 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004713 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004853 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004951 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004721 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004705 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004686 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004616 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004942 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004577 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004587 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004672 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004920 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004623 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004340 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004615 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005041 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004498 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004180 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004642 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004715 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004713 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005347 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004778 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004917 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004934 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.005021 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005047 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004657 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005098 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004681 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005380 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004563 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004922 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004838 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.027388 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004870 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004210 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004496 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004696 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004305 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004684 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004578 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004600 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004701 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004859 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004930 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004840 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004798 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004618 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004619 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004522 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004324 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005532 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004561 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004530 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004525 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004759 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004933 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004980 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004654 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004564 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004597 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004665 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.005009 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004765 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004867 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004662 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004562 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004649 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004657 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.03 MB) transferred to GPU in 0.004462 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004788 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 27 dense feature groups (0.02 MB) transferred to GPU in 0.004485 secs. 1 sparse feature groups
# LGBMRegressor(bagging_freq=7, colsample_bytree=0.9, device_type='gpu',
#               max_depth=17, metric='auc', n_estimators=1000, num_leaves=14,
#               objective='regression', random_state=314, silent=True,
#               subsample=0.8)

# %%
print('Training accuracy: {:.4f}'.format(model.score(X_train,y_train)))
print('Training accuracy: {:.4f}'.format(model.score(X_test,y_test)))
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# Training accuracy: 0.9998
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# Training accuracy: 0.8906
